# %% [markdown]
# # Amazon SageMaker AutoPilot (ML Tabular Problem)

# %% [markdown]
# Amazon SageMaker Autopilot automatically trains and tunes the best machine learning models for classification or regression, based on your data while allowing to maintain full control and visibility.
#
# Building machine learning (ML) models has traditionally required a binary choice. On one hand, you could manually prepare the features, select the algorithm, and optimize the model parameters in order to have full control over the model design and understand all the thought that went into creating it. However, this approach requires deep ML expertise. On the other hand, if you don’t have that expertise, you could use an automated approach (AutoML) to model generation that takes care of all of the heavy lifting, but provides very little visibility into how the model was created. While a model created with AutoML can work well, you may have less trust in it because you can’t understand what went into it, you can’t recreate it, and you can’t learn best practices which may help you in the future.
#
# Amazon SageMaker Autopilot eliminates this choice, allowing you to automatically build machine learning models without compromises. With SageMaker Autopilot, you provide a tabular dataset and select the target column to predict, which can be a number (such as a house price, called regression), or a category (such as spam/not spam, called classification). SageMaker Autopilot will automatically explore different solutions to find the best model. You then can directly deploy the model to production with just one click, or iterate on the recommended solutions with Amazon SageMaker Studio to further improve the model quality.

# %% [markdown]
# ![AUTOML]('./img/SageMaker-AutoML.png')

# %%
import sagemaker
import smdebug_rulesconfig as rule_configs
import boto3
import os
import sys
import numpy as np 
import pandas as pd

print(sagemaker.__version__)
# Out:
# 1.64.0

# %%
sess   = sagemaker.Session()
bucket = 'hyunjoon-sagemaker-us' # or sess.default_bucket()                     
prefix = 'sagemaker/DEMO-automl-dm'
region = boto3.Session().region_name

print('Sagemaker session :', sess)
print('S3 bucket :', bucket)
print('Prefix :', prefix)
print('Region selected :', region)
# Out:
# Sagemaker session : <sagemaker.session.Session object at 0x00000163480C9E88>
# S3 bucket : hyunjoon-sagemaker-us
# Prefix : sagemaker/DEMO-automl-dm
# Region selected : us-west-2

# %% [markdown]
# # 1. Load Data

# %% [markdown]
# Download the direct marketing dataset from UCI's ML Repository.
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed.

# %% [markdown]
# [Download Dataset Manually here](https://archive.ics.uci.edu/ml/datasets/bank+marketing)

# %% [markdown]
# #### Wget Download
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip \
# !unzip -o bank-additional.zip

# %%
path = 'C:\\Users\\bokhy\\Desktop\\Python\\github\\amazon-sagemaker\\data'

# %%
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page

# Read data
data = pd.read_csv(os.path.join(path, 'bank-additional-full.csv'), sep=';')
data.head() # Show the first 10 lines
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           1.1          93.994          -36.4      4.857       5191.0  no
# 1           1.1          93.994          -36.4      4.857       5191.0  no
# 2           1.1          93.994          -36.4      4.857       5191.0  no
# 3           1.1          93.994          -36.4      4.857       5191.0  no
# 4           1.1          93.994          -36.4      4.857       5191.0  no

# %% [markdown]
# # 2. PreProcess the Data

# %%
# Splitting the dataset
train_data, test_data, _ = np.split(data.sample(frac=1, random_state=123), 
                                                  [int(0.95 * len(data)), int(len(data))])  

# Save to CSV files
train_data.to_csv('./data/automl-train.csv', index=False, header=True, sep=',') # Need to keep column names
test_data.to_csv('./data/automl-test.csv', index=False, header=True, sep=',')

# %% [markdown]
# # 3. Upload data to S3 bucket

# %% [markdown]
# ### No preprocessing on data is needed in SageMaker AutoML!

# %%
s3_input_data = sess.upload_data(path="./data/automl-train.csv", key_prefix=prefix + "/input")
print(s3_input_data)
# Out:
# s3://sagemaker-us-west-2-570447867175/sagemaker/DEMO-automl-dm/input/automl-train.csv

# %% [markdown]
# # 4. Setting up SageMaker AutoPilot training parameter

# %% [markdown]
# Doc: https://sagemaker.readthedocs.io/en/stable/automl.html

# %% [markdown]
# You would need to create a role in [IAM Console](https://console.aws.amazon.com/iam)

# %% [markdown]
# For detailed instruction, please refer to this [AWS Developer Guie](https://docs.aws.amazon.com/glue/latest/dg/create-an-iam-role-sagemaker-notebook.html)

# %%
from sagemaker.automl.automl import AutoML


role = 'arn:aws:iam::570447867175:role/SageMakerNotebookRole' # pass your IAM role name

auto_ml_job = AutoML(
    role = role,                                              # IAM role
    sagemaker_session = sess,                                  
    target_attribute_name = 'y',                              # The column we want to predict 
    output_path = 's3://{}/{}/output'.format(bucket,prefix),  # Save output artifacts here
    max_candidates = 100,                                     # Number of models (Defaut: 500) 
    max_runtime_per_training_job_in_seconds = 600, 
    total_job_runtime_in_seconds = 3600
)

# %% [markdown]
# # 5. Start Training

# %%
auto_ml_job.fit(inputs=s3_input_data, logs=False, wait=False)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
auto_ml_job.describe_auto_ml_job()
# Out:
# {'AutoMLJobName': 'automl-2020-06-18-07-27-05-187',
#  'AutoMLJobArn': 'arn:aws:sagemaker:us-west-2:570447867175:automl-job/automl-2020-06-18-07-27-05-187',
#  'InputDataConfig': [{'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#      'S3Uri': 's3://sagemaker-us-west-2-570447867175/sagemaker/DEMO-automl-dm/input/automl-train.csv'}},
#    'TargetAttributeName': 'y'}],
#  'OutputDataConfig': {'S3OutputPath': 's3://hyunjoon-sagemaker-us/sagemaker/DEMO-automl-dm/output'},
#  'RoleArn': 'arn:aws:iam::570447867175:role/SageMakerNotebookRole',
#  'AutoMLJobConfig': {'CompletionCriteria': {'MaxCandidates': 100,
#    'MaxRuntimePerTrainingJobInSeconds': 600,
#    'MaxAutoMLJobRuntimeInSeconds': 3600},
#   'SecurityConfig': {'EnableInterContainerTrafficEncryption': False}},
#  'CreationTime': datetime.datetime(2020, 6, 18, 0, 27, 5, 278000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2020, 6, 18, 0, 27, 7, 353000, tzinfo=tzlocal()),
#  'AutoMLJobStatus': 'InProgress',
#  'AutoMLJobSecondaryStatus': 'AnalyzingData',
#  'GenerateCandidateDefinitionsOnly': False,
#  'ResponseMetadata': {'RequestId': '83a30c7e-4605-4118-81e8-d016be8c5e54',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '83a30c7e-4605-4118-81e8-d016be8c5e54',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '899',
#    'date': 'Thu, 18 Jun 2020 07:27:07 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Tracking the progress of the AutoPilot job
# SageMaker AutoPilot job consists of **four high-level steps** :

# %% [markdown]
# 1. Data Preprocessing, where the dataset is split into train and validation sets. \
# 2. Recommending Pipelines, where the dataset is analyzed and SageMaker AutoPilot comes up with a list of ML pipelines that should be tried out on the dataset. \
# 3. Automatic Feature Engineering, where SageMaker AutoPilot performs feature transformation on individual features of the dataset as well as at an aggregate level. \
# 4. ML pipeline selection and hyperparameter tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline). \

# %%
from time import sleep

job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('AnalyzingData'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Data analysis complete")
# Out:
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress FeatureEngineering
# Data analysis complete

# %% [markdown]
# ### Viewing notebooks generated by SageMaker AutoPilot

# %% [markdown]
# Once data analysis is complete, SageMaker AutoPilot generates **two notebooks**:
# 1. Data exploration \
# 2. Candidate definition \

# %%
job = auto_ml_job.describe_auto_ml_job()
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']

print(job_candidate_notebook)
print(job_data_notebook)
# Out:
# s3://hyunjoon-sagemaker-us/sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# s3://hyunjoon-sagemaker-us/sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# Copy these two notebooks and open these notebooks. There are useful information

# %% [markdown]
# Run following commands in Jupyter notebook
# or in CMD (command prompt) in Windows

# %%
# !aws s3 cp s3://hyunjoon-sagemaker-us/sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb candidate.ipynb
# !aws s3 cp s3://hyunjoon-sagemaker-us/sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb DataExploration.ipynb
# Out:
# usage: aws [options] <command> <subcommand> [<subcommand> ...] [parameters]
# To see help text, you can run:
#
#   aws help
#   aws <command> help
#   aws <command> <subcommand> help
# aws: error: the following arguments are required: paths
# usage: aws [options] <command> <subcommand> [<subcommand> ...] [parameters]
# To see help text, you can run:
#
#   aws help
#   aws <command> help
#   aws <command> <subcommand> help
# aws: error: the following arguments are required: paths

# %% [markdown]
# SageMaker AutoPilot then launches feature engineering, and prepares different training and validation datasets.

# %%
job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('FeatureEngineering'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Feature engineering complete")
# Out:
# Feature engineering complete

# %% [markdown]
# Once feature engineering is finished, SageMaker AutoPilot launches Auto Model Tuning on the different candidates. While model tuning is running, we can explore its progress with SageMaker Experiments.

# %%
import pandas as pd
from sagemaker.analytics import ExperimentAnalytics, TrainingJobAnalytics

exp = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=job['AutoMLJobName'] + '-aws-auto-ml-job',
)

df = exp.dataframe()
print("Number of jobs: ", len(df))

# Move metric to first column
# df = pd.concat([df['ObjectiveMetric - Max'], df.drop(['ObjectiveMetric - Max'], axis=1)], axis=1)
# Show top 5 jobs
# df.sort_values('ObjectiveMetric - Max', ascending=0)[:5]
df[:10]
# Out:
# Number of jobs:  25
#                                   TrialComponentName  \
# 0  tuning-job-1-46cb7fcbd7294bf7be-004-ea1f352a-a...
# 1  tuning-job-1-46cb7fcbd7294bf7be-003-11bb7b5c-a...
# 2  tuning-job-1-46cb7fcbd7294bf7be-006-e57d8a5c-a...
# 3  tuning-job-1-46cb7fcbd7294bf7be-002-2f2ca630-a...
# 4  tuning-job-1-46cb7fcbd7294bf7be-010-7363e360-a...
#
#                                          DisplayName  \
# 0  tuning-job-1-46cb7fcbd7294bf7be-004-ea1f352a-a...
# 1  tuning-job-1-46cb7fcbd7294bf7be-003-11bb7b5c-a...
# 2  tuning-job-1-46cb7fcbd7294bf7be-006-e57d8a5c-a...
# 3  tuning-job-1-46cb7fcbd7294bf7be-002-2f2ca630-a...
# 4  tuning-job-1-46cb7fcbd7294bf7be-010-7363e360-a...
#
#                                            SourceArn  \
# 0  arn:aws:sagemaker:us-west-2:570447867175:train...
# 1  arn:aws:sagemaker:us-west-2:570447867175:train...
# 2  arn:aws:sagemaker:us-west-2:570447867175:train...
# 3  arn:aws:sagemaker:us-west-2:570447867175:train...
# 4  arn:aws:sagemaker:us-west-2:570447867175:train...
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 0  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...                      1.0
# 1  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...                      1.0
# 2  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...                      1.0
# 3  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...                      1.0
# 4  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...                      1.0
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB _tuning_objective_metric  \
# 0          ml.m5.4xlarge                      50.0      validation:accuracy
# 1          ml.m5.4xlarge                      50.0      validation:accuracy
# 2          ml.m5.4xlarge                      50.0      validation:accuracy
# 3          ml.m5.4xlarge                      50.0      validation:accuracy
# 4          ml.m5.4xlarge                      50.0      validation:accuracy
#
#       alpha  colsample_bytree       eta      gamma    lambda  max_depth  \
# 0  0.001664          0.593890  0.015010  50.795290  1.537836       22.0
# 1  0.000296          0.345105  0.002555   0.041776  0.000250        7.0
# 2  0.001664          0.593890  0.015010  50.795290  1.537836       22.0
# 3  0.000296          0.345105  0.002555   0.041776  0.000250        7.0
# 4  0.001664          0.593890  0.015010  50.795290  1.537836       22.0
#
#    min_child_weight  num_round        objective  subsample  \
# 0         31.774205        5.0  binary:logistic   0.607919
# 1          0.019499      163.0  binary:logistic   0.598289
# 2         31.774205        5.0  binary:logistic   0.607919
# 3          0.019499      163.0  binary:logistic   0.598289
# 4         31.774205        5.0  binary:logistic   0.607919
#
#   SageMaker.ModelName SageMaker.ModelPrimary.DataUrl  \
# 0                 NaN                            NaN
# 1                 NaN                            NaN
# 2                 NaN                            NaN
# 3                 NaN                            NaN
# 4                 NaN                            NaN
#
#   SageMaker.ModelPrimary.Image processor_module sagemaker_program  \
# 0                          NaN              NaN               NaN
# 1                          NaN              NaN               NaN
# 2                          NaN              NaN               NaN
# 3                          NaN              NaN               NaN
# 4                          NaN              NaN               NaN
#
#   sagemaker_submit_directory input_channel_mode job_name label_col
# 0                        NaN                NaN      NaN       NaN
# 1                        NaN                NaN      NaN       NaN
# 2                        NaN                NaN      NaN       NaN
# 3                        NaN                NaN      NaN       NaN
# 4                        NaN                NaN      NaN       NaN

# %%
job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status in ('ModelTuning'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
    print("Model tuning complete")
# Out:
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# InProgress ModelTuning
# Completed MaxCandidatesReached
# Model tuning complete

# %% [markdown]
# # 6. Model Deploy

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())

endpoint_name = job['AutoMLJobName']+'-'+timestamp

print(endpoint_name)
# Out:
# automl-2020-06-18-07-27-05-187-18-08-28-52

# %%
auto_ml_job.deploy(
    initial_instance_count = 1,
    instance_type = 'ml.m4.xlarge',
    endpoint_name = endpoint_name
)
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!

# %% [markdown]
# # 7. Predict with the test set

# %% [markdown]
# - From https://gitlab.com/juliensimon/awsdevdays2020/-/blob/master/mls2/XGBoost-AutoPilot.ipynb

# %%
from sagemaker.predictor import csv_serializer, RealTimePredictor
from sagemaker.content_types import CONTENT_TYPE_CSV

predictor = RealTimePredictor(
    endpoint=endpoint_name, 
    sagemaker_session=sess, 
    serializer=csv_serializer,
    content_type=CONTENT_TYPE_CSV, 
    accept='text/csv'
)

# %%
tp = tn = fp = fn = count = 0

with open('./data/automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   # Skip header
        l = l.split(',')  # Split CSV line into feature array
        label = l[-1]     # Store 'yes'/'no' label
        l = l[:-1]        # Remove label
        l = ','.join(l)   # Rebuild CSV line without label
                
        response = predictor.predict(l)
        response = response.decode("utf-8")
        #print ("label %s response %s" %(label,response))

        if 'yes' in label:
            # Sample is positive
            if 'yes' in response:
                # True positive
                tp=tp+1
            else:
                # False negative
                fn=fn+1
        else:
            # Sample is negative
            if 'no' in response:
                # True negative
                tn=tn+1
            else:
                # False positive
                fp=fp+1
        count = count+1
        if (count % 100 == 0):   
            sys.stdout.write(str(count)+' ')
            
#Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall    = tn/(tn+fn)
f1        = (2*precision*recall)/(precision+recall)

print ("%.4f %.4f %.4f %.4f" % (accuracy, precision, recall, f1))
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 1769 53
# 111 127
# 0.9204 0.7056 0.9410 0.8064

# %% [markdown]
# # 8. Close the SageMaker Instance

# %% [markdown]
# - To make sure we don't get charged after the training/inference is over, we have to delete the endpoint.

# %%
sess.delete_endpoint(predictor.endpoint)

# %% [markdown]
# - Also, SageMaker AutoML job creates many underlying artifacts such as dataset splits, preprocessing scripts, preprocessed data, etc. Let's delete them too!

# %%
import boto3

job_outputs_prefix = '{}/output/{}'.format(prefix, job['AutoMLJobName'])
print(job_outputs_prefix)

s3_bucket =boto3.resource('s3').Bucket(bucket)
# Out:
# sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187

# %%
s3_bucket.objects.filter(Prefix=job_outputs_prefix).delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '18C196F4C827B924',
#    'HostId': 'tqogCt29afGNln2RemIpKQ1c3Y0H1+midZ12x+GhVGOlOvl+ZeW4S0tfVqKhUUAJRzVwDSOT0rw=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'tqogCt29afGNln2RemIpKQ1c3Y0H1+midZ12x+GhVGOlOvl+ZeW4S0tfVqKhUUAJRzVwDSOT0rw=',
#     'x-amz-request-id': '18C196F4C827B924',
#     'date': 'Thu, 18 Jun 2020 08:44:36 GMT',
#     'connection': 'close',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_7.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_84.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_34.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_74.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/sagemaker_automl/steps.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_20.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_3.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/dpp7.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/data-processor-models/automl-202-dpp9-1-19fab48cf87249888e30917e65d8f7aae232f2273fdd4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/sagemaker_automl/README.md'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_49.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/trainer.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_8.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_87.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/dpp4.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_77.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_80.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/sagemaker_automl/interactive_runner.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_11.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_19.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_62.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_26.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/dpp3.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_73.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_38.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_0.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/README.md'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/dpp1.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_57.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_31.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_29.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_47.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_45.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/setup.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_35.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_21.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_50.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/MANIFEST.in'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_99.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_6.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_39.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_75.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_76.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_69.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_72.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_46.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_83.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_60.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/validation/chunk_2.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_56.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp0/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/dpp0.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_61.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/data-processor-models/automl-202-dpp4-1-17c154b774814bae8690ca7b85ad7fd12227e648225a4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp7/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/preprocessed-data/tuning_data/train/chunk_24.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/notebooks/sagemaker_automl/common.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/data-processor-models/automl-202-dpp2-1-63ca4747722b4cbfaaac39ca6d19d9df5ac11f8ecee14/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/sagemaker-automl-candidates/pr-1-c96ac63cfc0240aca57b6e1b4efe6d295f229d0ef34547408b311743d1/generated_module/candidate_data_processors/sagemaker_serve.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp3/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp5/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp2/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp4/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp6/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp1/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_22.csv.out'},
# ...
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp5-xgb/tuning-job-1-46cb7fcbd7294bf7be-040-11d4f667/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-090-e781de1f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp5-xgb/tuning-job-1-46cb7fcbd7294bf7be-005-373d3b1a/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-017-b5dfa4fe/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-053-f5c1bcdf/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-093-31e95921/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-069-fcf3b303/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp5-xgb/tuning-job-1-46cb7fcbd7294bf7be-035-cf05b3b0/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-065-5e815a63/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-091-f33d12db/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp3-xgb/tuning-job-1-46cb7fcbd7294bf7be-034-211983b1/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp1-xgb/tuning-job-1-46cb7fcbd7294bf7be-030-8f0ce12d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-052-5e2796d3/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-057-002156c0/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-070-8378552b/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp5-xgb/tuning-job-1-46cb7fcbd7294bf7be-032-d3afe292/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp9-xgb/tuning-job-1-46cb7fcbd7294bf7be-019-b12c59ce/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-067-6365b33c/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp8-xgb/tuning-job-1-46cb7fcbd7294bf7be-031-2dccf6d2/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-048-434d5976/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-083-1a745c06/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp2-ll/tuning-job-1-46cb7fcbd7294bf7be-089-3aa7d366/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-074-789686ea/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp9-xgb/tuning-job-1-46cb7fcbd7294bf7be-023-ffc58d0f/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp3-xgb/tuning-job-1-46cb7fcbd7294bf7be-076-4bbdd9db/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp0-xgb/tuning-job-1-46cb7fcbd7294bf7be-020-9b6f20ef/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-058-5d889b62/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp6-xgb/tuning-job-1-46cb7fcbd7294bf7be-015-68ed319d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-061-fd1cf914/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-043-7a9bb74e/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-082-fc9032dd/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-055-2a5bbd93/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp3-xgb/tuning-job-1-46cb7fcbd7294bf7be-013-fe8c5e5a/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp1-xgb/tuning-job-1-46cb7fcbd7294bf7be-038-2b658536/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp3-xgb/tuning-job-1-46cb7fcbd7294bf7be-044-103e5da2/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp8/csv/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-051-98513137/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-095-29c57512/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp6-xgb/tuning-job-1-46cb7fcbd7294bf7be-012-6f2ef493/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp5-xgb/tuning-job-1-46cb7fcbd7294bf7be-001-00df0990/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-062-f4ec71e1/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-092-721b8e1c/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp3-xgb/tuning-job-1-46cb7fcbd7294bf7be-026-723fa048/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp1-xgb/tuning-job-1-46cb7fcbd7294bf7be-010-7363e360/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/tuning/automl-202-dpp4-xgb/tuning-job-1-46cb7fcbd7294bf7be-084-9daa4b29/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2020-06-18-07-27-05-187/transformed-data/dpp9/csv/train/chunk_94.csv.out'}]}]
